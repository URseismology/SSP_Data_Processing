# %%
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Author: Tolulope Olugboji
# Date:  Nov. 22, 2013 | Original: October 21, 2013 |
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# Objective:   Run RF stacks [For RFAnalysis] for All SAC Data from 
#              OCEAN ISLANDS ...
#
#    1. Azimuth Stacks
#    2. Epicentral Sweeps
#    3. Harmonic Stacks
#    4. Summary Stacks
#    5. Multi-HK Stacks
#
#
#
# Code uses T1 header to create QC Manifest ...
#
#

import subprocess
import time, sys, os

#p = subprocess.Popen(["ls", "-l", "/etc/resolv.conf"], stdout=subprocess.PIPE)
#output, err = p.communicate()
#print "*** Running ls -l command ***\n", output


#0.0 Run Synthetics and Harmonics For A particular anisotropic model
#def runSynthetics

# 1.0 Epicentral Crude Stack
def runRFstackByEpic(manifestURL, outURL, azimWinMin, azimWinMax, azimWinStep, epicWinMin, epicWinMax, epicWinStep, freqCut):
    

    epicOption = str(azimWinMin) + '/' + str(azimWinMax) + '/' + str(epicWinMin) + '/' + str(epicWinMax) + '/' + str(epicWinStep)
    
    CommandArgumentList = ['RecFuncHarmonic', '-L' + manifestURL,
                           '-F' + str(freqCut), '-T60', '-O' + outURL,
                          '-B2', '-S0/50', '-E' + epicOption, '-H1' , '-V1', '-R0.7']
    
    #azimOption = str(azimWinMin) + '/' + str(azimWinMax) + '/'  + str(azimWinStep)
    
    #CommandArgumentList = ['RecFuncHarmonic', '-L' + manifestURL,
    #                       '-F' + str(freqCut), '-T60', '-O' + outURL,
    #                       '-B1', '-S0/50', '-A' + azimOption, '-H0', '-V1', '-R1.0']

    
    p = subprocess.Popen(CommandArgumentList, stdout=subprocess.PIPE) 
    output, err = p.communicate()
    print "*** Running RecFuncHarmonic on ", outURL, "errors?: \n", err, output
    

# 2.0 Azimuth Crude Stack
def runRFstackByAzim(manifestURL, outURL, azimWinMin, azimWinMax, azimWinStep, freqCut):

    azimOption = str(azimWinMin) + '/' + str(azimWinMax) + '/'  + str(azimWinStep)
    
    CommandArgumentList = ['RecFuncHarmonic', '-L' + manifestURL,
                           '-F' + str(freqCut), '-T60', '-O' + outURL,
                           '-B1', '-S0/50', '-A' + azimOption, '-H1', '-V1', '-R0.55']

    
    p = subprocess.Popen(CommandArgumentList, stdout=subprocess.PIPE) 
    output, err = p.communicate()
    print "*** Running RecFuncHarmonic on ", outURL, "errors?: \n", err, output
    
def runRFstackByAzimWithRot(manifestURL, outURL, azimWinMin, azimWinMax, azimWinStep, freqCut, headCode,rotAngle):

    azimOption = str(azimWinMin) + '/' + str(azimWinMax) + '/'  + str(azimWinStep)
    
    CommandArgumentList = ['RecFuncHarmonic', '-L' + manifestURL,
                           '-F' + str(freqCut), '-T60', '-O' + outURL,
                           '-B1', '-S0/50', '-A' + azimOption, '-H'+str(headCode), '-V1', '-R0.5',
                           '-Rh/'+str(rotAngle)]

    
    p = subprocess.Popen(CommandArgumentList, stdout=subprocess.PIPE) 
    output, err = p.communicate()
    print "*** Running RecFuncHarmonic on ", outURL, "errors?: \n", err, output
    
# 3.0 Harmonic Crude Stack
def runHarmonicRFstack(manifestURL, outURL, freqCut):
    
    CommandArgumentList = ['RecFuncHarmonic', '-L' + manifestURL,
                           '-F' + str(freqCut), '-T30', '-O' + outURL,
                           '-S1/100', '-H1', '-V1', '-R0.55']

    
    p = subprocess.Popen(CommandArgumentList, stdout=subprocess.PIPE) 
    output, err = p.communicate()
    print "*** Running RecFuncHarmonic on ", outURL, "errors?: \n", err, output
    
# 3.1 Harmonic Crude Stack - With horizontal rotation [Jap OBS Data]
def runHarmonicRFstackWithRot(manifestURL, outURL, freqCut, rotAngle):
    
    CommandArgumentList = ['RecFuncHarmonic', '-L' + manifestURL,
                           '-F' + str(freqCut), '-T60', '-O' + outURL,
                           '-S1/100', '-H1', '-V1', '-R0.55', '-Rh/'+str(rotAngle)]

    
    p = subprocess.Popen(CommandArgumentList, stdout=subprocess.PIPE) 
    output, err = p.communicate()
    #print "*** Running RecFuncHarmonic on ", outURL, "errors?: \n", err, output    

# 4.0 Azimuth Stack With Migration ...
def runRFstackByAzimWithMigrate(manifestURL, outURL, migrateURL, migrateDepth,
                                azimWinMin, azimWinMax, azimWinStep, freqCut):

    azimOption = str(azimWinMin) + '/' + str(azimWinMax) + '/'  + str(azimWinStep)
    
    CommandArgumentList = ['RecFuncHarmonic', '-L' + manifestURL,
                           '-F' + str(freqCut), '-T60', '-O' + outURL,
                           '-B1', '-S0/50', '-A' + azimOption, '-H1', '-V1', '-R2.0',
                           '-M0/'+str(migrateDepth), '-I'+migrateURL]

    
    p = subprocess.Popen(CommandArgumentList, stdout=subprocess.PIPE) 
    output, err = p.communicate()
    print "*** Running RecFuncHarmonic on ", outURL, "errors?: \n", err, output
    
# 5.0 Harmonic Stack With Migration ...
def runHarmonicRFstackWithMigrate(manifestURL, outURL, migrateURL, migrateDepth, freqCut):
    
    CommandArgumentList = ['RecFuncHarmonic', '-L' + manifestURL,
                           '-F' + str(freqCut), '-T60', '-O' + outURL,
                           '-B1', '-S1/100', '-H1', '-V1', '-R0.55',
                           '-M0/'+str(migrateDepth), '-I'+migrateURL]

    
    p = subprocess.Popen(CommandArgumentList, stdout=subprocess.PIPE) 
    output, err = p.communicate()
    print "*** Running RecFuncHarmonic on ", outURL, "errors?: \n", err, output
    
def runHarmonicRFstackWithMigrateRot(manifestURL, outURL, migrateURL, migrateDepth, freqCut, rotAngle, lqtBias):
    RFcommand = 'RecFuncHarmonicJack'
    
    CommandArgumentList = [RFcommand, '-L' + manifestURL,
                           '-F' + str(freqCut), '-T60', '-O' + outURL,
                           '-B1', '-S1/100', '-H1', '-V1', '-R'+str(lqtBias),
                           '-M0/'+str(migrateDepth), '-I'+migrateURL, '-Rh/'+str(rotAngle)]

    
    p = subprocess.Popen(CommandArgumentList, stdout=subprocess.PIPE) 
    output, err = p.communicate()
    print "*** Running RecFuncHarmonic on ", outURL, "errors?: \n", err, output
    
    
# 6.0 Epicentral Stack With Migration - also include routine to do reverberation time calculations ..
def runRFstackByEpicWithMigrate(manifestURL, outURL, migrateURL, migrateDepth, 
                     azimWinMin, azimWinMax, azimWinStep, epicWinMin, epicWinMax, epicWinStep, freqCut, bias, tD):
    

    epicOption = str(azimWinMin) + '/' + str(azimWinMax) + '/' + str(epicWinMin) + '/' + str(epicWinMax) + '/' + str(epicWinStep)
    
    
    #$execDir/RecFuncHarmonic -O$modelDir$statCode/$statCode -L$RecordDir/$statCode".in" \
    #-Mp/$layerH -E0/350/30/100/5 -V -I$dataFile  > /dev/null 
    
    # run migrate before phase print
    lqtBias = bias;
    RFcommand = 'RecFuncHarmonicJack'
    
    CommandArgumentList = [RFcommand, '-L' + manifestURL,
                           '-F' + str(freqCut), '-T60', '-O' + outURL,
                          '-B2', '-S0/50', '-E' + epicOption, '-H1' , '-V1', '-R'+str(lqtBias),
                          '-M0/'+str(migrateDepth), '-I'+migrateURL]
    
    #print "*** Running RecFuncHarmonic on ", outURL, "errors?: \n", err, output
    # Now construct phase print ... do 2ce or 3ce ? Just once above underplated layer
    reverbModel = "/Users/tmo22/Documents/JapaneseProject/reverbAnalysis/2Models/2LyrMod_T06.txt"
    #outURLP = "/Users/tmo22/Documents/OlugbojiPark2013/ParkOlugboji2012/SeismicData/SACbyStation/AllStationProcessed/reverbAnalysis/phaseTiming/"
    
    outURLPrint = outURL+ '_L1' # First layer at 13 km in demo model
    CommandArgumentList2 = [RFcommand, '-L' + manifestURL,
                           '-F' + str(freqCut), '-T60', '-O' + outURLPrint,
                          '-B2', '-S0/50', '-E' + epicOption, '-H1' , '-V1', '-R'+str(lqtBias),
                           '-I'+reverbModel, '-Mp/'+str(tD)]
    p = subprocess.Popen(CommandArgumentList2, stdout=subprocess.PIPE) 
    output, err = p.communicate()
    
    # For three layer model. middle layer - L1b - comment out if only using 2Layer model.
    outURLPrint = outURL+ '_L1b' # First layer at 13 km in demo model
    CommandArgumentList2 = [RFcommand, '-L' + manifestURL,
                           '-F' + str(freqCut), '-T60', '-O' + outURLPrint,
                          '-B2', '-S0/50', '-E' + epicOption, '-H1' , '-V1', '-R'+str(lqtBias),
                           '-I'+reverbModel, '-Mp/4']
    p = subprocess.Popen(CommandArgumentList2, stdout=subprocess.PIPE) 
    output, err = p.communicate()
    
    outURLPrint = outURL + '_L2' # Second layer at 30 km in demo model
    CommandArgumentList2 = [RFcommand, '-L' + manifestURL,
                           '-F' + str(freqCut), '-T60', '-O' + outURLPrint,
                          '-B2', '-S0/50', '-E' + epicOption, '-H1' , '-V1', '-R'+str(lqtBias),
                           '-I'+reverbModel, '-Mp/22']
    p = subprocess.Popen(CommandArgumentList2, stdout=subprocess.PIPE) 
    output, err = p.communicate()

    
    p = subprocess.Popen(CommandArgumentList, stdout=subprocess.PIPE) 
    output, err = p.communicate()
    print "*** Running RecFuncHarmonic on ", outURL, "errors?: \n", err, output
    
    p = subprocess.Popen(CommandArgumentList2, stdout=subprocess.PIPE) 
    output, err = p.communicate()
    
    
def runRFmultiHKinversion(manifestURL, outURL, srchURL,freqCut ):
    
    CommandArgumentList = ['RFVelStck', '-L' + manifestURL,
                           '-F' + str(freqCut), '-T60', '-O' + outURL,
                           '-S' + srchURL, '-H1', '-V1', '-R1.0', '-I5']
    
    p = subprocess.Popen(CommandArgumentList, stdout=subprocess.PIPE) 
    output, err = p.communicate()
    print "*** Running multiHK time domain inversion ", outURL, "errors?: \n", err, output
    
                        

##### OBS Workflow directory here
manifestDir = "/Users/tmo22/Documents/JapaneseProject/Manifest/CCP_Manifest/CS_Manifest/"

migrateDir = "/Users/tmo22/Documents/JapaneseProject/FwrdModels/"
imagesDir = "/Users/tmo22/Documents/JapaneseProject/Images/RFimages/"
shellDir = "/Users/tmo22/Documents/JapaneseProject/RFscripts/"
        
################   WORKFLOW Here ... Run RFs with different stacking modules. Work on display later ...
synthDir = "/Users/tmo22/Documents/OlugbojiPark2013/ParkOlugboji2012/SeismicData/SACbyStation/AllStationProcessed/SACFiles/"
#manifestDir = "/Users/tmo22/Documents/OlugbojiPark2013/ParkOlugboji2012/SeismicData/SACbyStation/AllStationProcessed/Manifest/"
#migrateDir = "/Users/tmo22/Documents/OlugbojiPark2013/ParkOlugboji2012/SeismicData/SACbyStation/AllStationProcessed/FwrdModels/"
#imagesDir = "/Users/tmo22/Documents/OlugbojiPark2013/ParkOlugboji2012/SeismicData/SACbyStation/AllStationProcessed/RFImages/"
#shellDir = "/Users/tmo22/Documents/OlugbojiPark2013/ParkOlugboji2012/SeismicData/SACbyStation/AllStationProcessed/RFScripts/"
            
DataQuals = ['All/', 'Pass/', 'Fail/']

## Epicentral sectors here 
#'XMAS':[150, 300]

sector = {'T06':[100, 340], 
          'T09':[0, 340],
          'T01':[0, 340],
          'T05':[0, 340],
          'T03':[0, 340],
          'KIP':[225, 360],
          'JOHN':[180, 360],
          'TARA':[225, 315],
          'KWAJ':[225, 360],
          'WAKE':[225, 360],
          'XMAS':[150, 300],} 


freqCut = 1.0

#RFstacks = ["AzimuthStacks", "EpicentralSweeps", "HarmonicStacks", "MigratedStacks", "SummaryStacks"]
RFstacks = ["AzimuthStacks",  "HarmonicStacks", "MigratedStacks", "EpicentralSweeps"]
migStacks = ["AzimuthStacks", "HarmonicStacks", "EpicentralSweeps"]

# Frequency dependence, and depth migration parameters here ...
#freqCuts = [1.2, 1.4, 1.6, 1.8]
freqCuts = [1, 2, 3, 4, 5, 6]


migDepths = [1, 25, 50, 70]
migDepths = [0]
lqtBias = [0, 0.2, 0.5, 1]

#test muting of reverberations
migDepths = [0.2]
lqtBias = [0.55]
lqtBias = [0]
freqCuts = [1]


#outDir = "/Users/tmo22/Documents/JapaneseProject/RFDataStacks/Spectrum/"
#outDir = "/Users/tmo22/Documents/JapaneseProject/RFDataStacks/Spectrum_Const/"
outDir = "/Users/tmo22/Documents/JapaneseProject/RFDataStacks/MuteReverb/"

for DataQual in DataQuals[1:2]:
    
    #os.chdir(manifestDir+DataQual)
    #manifestFiles = get_ipython().getoutput(u'ls *.txt')

    #os.chdir(synthDir)
    #manifestFiles = !ls *_S.txt   # Synthetic Manfiest! Comment out if run on real data   
    #print 'MANIFEST', manifestFiles
    
    # Walk all manifest and parse into station type ...
    #manifestFiles = ['KIP.txt', 'POHA.txt', 'PTCN.txt', 'RPN.txt', 'TARA.txt', 'WAKE.txt', 'XMAS.txt']
    # comment this out for all stations
    manifestFiles = ['T06.txt']
    #manifestFiles = ['T01.txt', 'T02.txt', 'T03.txt', 'T05.txt',  'WP1.txt', 'T06.txt', 'T07.txt', 'T08.txt', 'T09.txt', 'T11.txt', 'T12.txt', 'T13.txt', 'T15.txt', 'T16.txt', 'T18.txt', 'T17.txt', 'T19.txt', 'T21.txt', 'WP2.txt']
    seisLABz = [63, 65, 43, 29, 60, 24, 22, 24, 49, 28, 39, 25, 34, 70, 70, 70, 75, 75, 75]
    
    rotAngle = 0
    
    for manifestFile, timeDep in zip(manifestFiles, seisLABz):
        # unComment line below to run manifests for all ocean island stations.
        # synthetic file manifest are tagged with _S
        if(1):
        #if (manifestFile == 'KIP_S.txt') :
        #if (manifestFile == 'PAYG.txt') :
                        
            #manifestURL = manifestDir+DataQual+manifestFile 
            manifestURL = manifestDir+manifestFile 
            migrateURL = migrateDir+manifestFile 
            
            # Synthetic Hacks
            #imagesDir = "/Users/tmo22/Documents/OlugbojiPark2013/ParkOlugboji2012/SeismicData/SACbyStation/AllStationProcessed/RFImages_Synth/"
            #manifestURL = manifestFile 
            # End Synthetic Hacks

            
            manifestHead = manifestFile.split("."); manifestHead = manifestHead[0]
            
            #for stack in RFstacks[0:2]:
            for bias in lqtBias:
                for stack in RFstacks[2:3]:

                    for freqCut in freqCuts[0:1]:
                        #stackURL = outDir + manifestHead + '/' stack + str(freqCut) +'Hz' 
                        stackURL = outDir + manifestHead + '/' + str(bias)  + '/' + manifestHead + '_'  

                        if ( stack == 'EpicentralSweeps'):

                            epicWinMin = 0
                            epicWinMax = 120
                            epicWinStep = 5

                            azimWinMin = 300 
                            azimWinMax = 360
                            azimWinStep = 6

                            # Epicentral Sweeps --- Forward Run
                            runRFstackByEpic(manifestURL, stackURL, azimWinMin, azimWinMax, azimWinStep, epicWinMin, epicWinMax, epicWinStep, freqCut)  

                            # Epicentral Sweeps --- Display with shell script
                            imageURL = imagesDir + stack + "/" +  str(freqCut) +'Hz/' + manifestHead

                            plotTitle = manifestHead+ ':' + str(azimWinMin)+ '-' + str(azimWinMax) + ',' + str(freqCut) + 'Hz'
                            CommandArgumentEpic = [shellDir+'PlotRFepic.sh', stackURL, imageURL, plotTitle]

                            p = subprocess.Popen(CommandArgumentEpic, stdout=subprocess.PIPE) 
                            output, err = p.communicate()
                            print "*** Running Display Script on ", stackURL, "errors?: ", err, "Output: ", output

                            print stackURL
                            print imageURL
                            print manifestURL

                        elif (stack == 'AzimuthStacks'):
                            print 'Running Azimuthal sweeps ...'


                            azimWinMin = 0 
                            azimWinMax = 360
                            azimWinStep = 3

                            # Azimuth Stack --- Forward Run
                            runRFstackByAzim(manifestURL, stackURL, azimWinMin, azimWinMax, azimWinStep, freqCut)  
                            #runRFstackByAzimWithRot(manifestURL, stackURL, azimWinMin, azimWinMax, azimWinStep, freqCut, 1, rotAngle) 

                            # Epicentral Sweeps --- Display with shell script
                            imageURL = imagesDir + stack + "/" +  str(freqCut) +'Hz/' + manifestHead
                            plotTitle = manifestHead+ ':' + str(azimWinMin)+ '-' + str(azimWinMax) + ',' + str(freqCut) + 'Hz'

                            CommandArgumentAzim = [shellDir+'PlotRFazim.sh', stackURL, imageURL, plotTitle]

                            # Azimuth Stack --- Display with shell script
                            p = subprocess.Popen(CommandArgumentAzim, stdout=subprocess.PIPE) 
                            output, err = p.communicate()
                            print "*** Running Display Script on ", stackURL, "errors?: ", err, "Output: ", output

                        elif (stack == 'HarmonicStacks'):
                            print 'Running Harmonic stacks ...'

                            # Harmonic Stack No Migration ... --- Forward Run
                            runHarmonicRFstack(manifestURL, stackURL, freqCut)  
                            #runHarmonicRFstackWithRot(manifestURL, stackURL, freqCut, rotAngle);

                            # Harmonic Stack --- Display with shell script
                            imageURL = imagesDir + stack + "/" +  str(freqCut) +'Hz/' + manifestHead
                            plotTitle = manifestHead+ ':'  + str(freqCut) + 'Hz'

                            CommandArgumentAzim = [shellDir+'PlotRFHarmonic.sh', stackURL, imageURL, plotTitle]

                            #Harmonic Stack --- Display with shell script
                            p = subprocess.Popen(CommandArgumentAzim, stdout=subprocess.PIPE) 
                            output, err = p.communicate()
                            print "*** Running Display Script on ", stackURL, "errors?: ", err, "Output: ", output


                        elif (stack == 'MigratedStacks'):

                            print "Migrate Model: ", migrateURL, "\n"

                            for migStack in migStacks[1:3]:

                                if (migStack == 'AzimuthStacks'):

                                    for migDepth in migDepths:
                                        imageURL = imagesDir + stack + "/" + migStack + "/" +                                     str(freqCut) +'Hz/' + manifestHead + '_Mig_' + str(migDepth)+'_'

                                        print 'Migrating @ Freq:', freqCut, "Hz \n OutDir: ", imageURL

                                        azimWinMin = 0 
                                        azimWinMax = 360
                                        azimWinStep = 10

                                        # Azimuth Stack --- Forward Run With Migration ...
                                        runRFstackByAzimWithMigrate(manifestURL, stackURL, migrateURL, migDepth,
                                                                    azimWinMin, azimWinMax, azimWinStep, freqCut)  

                                        # --- Display with shell script
                                        plotTitle = manifestHead+ ' Mig. to:' + str(migDepth) + 'km, @' + str(freqCut) + 'Hz'

                                        CommandArgumentAzim = [shellDir+'PlotRFazimMig.sh', stackURL, imageURL, plotTitle]

                                        # Azimuth Stack --- Display with shell script
                                        p = subprocess.Popen(CommandArgumentAzim, stdout=subprocess.PIPE) 
                                        output, err = p.communicate()
                                        print "*** Running Display Script on ", stackURL, "errors?: ", err, "Output: ", output

                                elif (migStack == 'HarmonicStacks'):

                                    for migDepth in migDepths[0:1]:

                                        imageURL = imagesDir + stack + "/" + migStack + "/" +                                     str(freqCut) +'Hz/' + manifestHead + '_Mig_' + str(migDepth)+'_'

                                        print 'In migration ... running Harmonic stacks ...'

                                        # Harmonic Stack No Migration ... --- Forward Run
                                        #runHarmonicRFstackWithMigrate(manifestURL, stackURL, migrateURL, migDepth, freqCut)  
                                        runHarmonicRFstackWithMigrateRot(manifestURL, stackURL, migrateURL, migDepth, freqCut, rotAngle, bias)  

                                        # Harmonic Stack --- Display with shell script
                                        #plotTitle = manifestHead+ ' Mig. to:' + str(migDepth) + 'km, @' + str(freqCut)  + 'Hz'


                                        #CommandArgumentAzim = [shellDir+'PlotRFHarmonicMig.sh', stackURL, imageURL, plotTitle]

                                        #Harmonic Stack --- Display with shell script
                                        #p = subprocess.Popen(CommandArgumentAzim, stdout=subprocess.PIPE) 
                                        #output, err = p.communicate()
                                        #print "*** Running Display Script on ", stackURL, "errors?: ", err, "Output: ", output

                                elif (migStack == 'EpicentralSweeps'):

                                    for migDepth in migDepths:
                                        imagesDir = "//Users/tmo22/Documents/JapaneseProject/reverbAnalysis/EpicStacksWithTiming/"
                                        imageURL = imagesDir +  manifestHead + '_' + str(bias)
                                        #imageURL = imagesDir + stack + "/" + migStack + "/" +                                     str(freqCut) +'Hz/' + manifestHead + '_Mig_' + str(migDepth)+'_'

                                        print 'Migrating @ Freq:', freqCut, "Hz \n OutDir: ", imageURL
                                        print manifestURL

                                        epicWinMin = 20
                                        epicWinMax = 150
                                        epicWinStep = 6

                                        #azimWinMin = sector[manifestHead][0] 
                                        #azimWinMax = sector[manifestHead][1]
                                        #azimWinStep = 6

                                        azimWinMin = sector['T06'][0] 
                                        azimWinMax = sector['T06'][1]
                                        azimWinStep = 6

                                        # Azimuth Stack --- Forward Run With Migration ...
                                        runRFstackByEpicWithMigrate(manifestURL, stackURL, migrateURL, migDepth,
                                                                    azimWinMin, azimWinMax, azimWinStep, epicWinMin,
                                                                    epicWinMax, epicWinStep, freqCut, bias, timeDep)  
                                        
                                        # Also run harmonic to extract constant term after migrate to depth ...
                                        runHarmonicRFstackWithMigrateRot(manifestURL, stackURL, migrateURL, migDepth, freqCut, rotAngle, bias)  

                                        # --- Display with shell script
                                        plotTitle = manifestHead+ ':' + str(azimWinMin)+ '-' + str(azimWinMax) + ':' + str(migDepth) + 'km, @' + str(freqCut) + 'Hz'

                                        # Plot Depth Migration ...
                                        #CommandArgumentAzim = [shellDir+'PlotRFepicMigDepth.sh', stackURL, imageURL, plotTitle]
                                        CommandArgumentAzim = [shellDir+'PlotRF_EpicReverbTime.sh', stackURL, imageURL, plotTitle]

                                        # Azimuth Stack --- Display with shell script
                                        p = subprocess.Popen(CommandArgumentAzim, stdout=subprocess.PIPE) 
                                        output, err = p.communicate()
                                        print "*** Running Display Script on ", stackURL, "errors?: ", err, "Output: ", output


                                        # Plot Time Migration ...
                                        #CommandArgumentAzim = [shellDir+'PlotRFepicMig.sh', stackURL, imageURL, plotTitle]

                                        # Azimuth Stack --- Display with shell script
                                        #p = subprocess.Popen(CommandArgumentAzim, stdout=subprocess.PIPE) 
                                        #output, err = p.communicate()
                                        #print "*** Running Display Script on ", stackURL, "errors?: ", err, "Output: ", output


                            print ""

                            # Azimuth Stack --- multiHKInversoion for WP1 Only...

                            #srchURL = "/Users/tmo22/Documents/JapaneseProject/Invert_Out/Invert_Params/WP1_GRDsrch.txt"
                            #outURL = "/Users/tmo22/Documents/JapaneseProject/Invert_Out/Invert_Result/WP1/WP1"
                            #runRFmultiHKinversion(manifestURL, outURL, srchURL, freqCut)
# Out:
# Migrate Model:  /Users/tmo22/Documents/JapaneseProject/FwrdModels/T06.txt
#
# In migration ... running Harmonic stacks ...
# *** Running RecFuncHarmonic on
#  /Users/tmo22/Documents/JapaneseProject/RFDataStacks/MuteReverb/T06/0/T06_ errors?:
# None Backward compatibility: run LQT rotation
# New Hack: run Horizontal rotation 0
#
#
#
# ***ScatteredWaveAnalysis(RF)*** Created by Tolulope Olugboji.
# ************************** Copyright 2010 Yale University. All rights reserved.
# **Option: Switch for LQT rotation activated with incidence angle bias: 0
# **Option: Direct Phase Migration with model: /Users/tmo22/Documents/JapaneseProject/FwrdModels/T06.txt
# **Option: Harmonic Stack Selected
# [Harmonic Stack Called With MWM migration]
# Staging Records using tagged headersTotal no of records: 235
# Record: 1 has the header no:  1 Tagged PhaseName: P
# Record: 2 has the header no:  1 Tagged PhaseName: P
# Record: 3 has the header no:  1 Tagged PhaseName: P
# ...

# %%
sector = {'PAYG':[300, 340], 
          'RPN':[300, 340],
          'PTCN':[300, 340],
          'RAR':[300, 340],
          'POHA':[300, 340],
          'KIP':[300, 340],
          'JOHN':[300, 340],
          'TARA':[300, 340],
          'KWAJ':[300, 340],
          'WAKE':[300, 340],
          'XMAS':[300, 340],} 

print sector['PAYG'][0]
